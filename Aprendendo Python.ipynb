# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexNogueira-22/AlexNogueira-22/blob/main/Aprendendo%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
# Um programa simples em Python
def saudacao(nome):
    return f"Olá, {Nogueira}! Bem-vindo ao mundo Python!"

# Testando a função
nome_usuario = input("Digite seu nome: ")
print(saudacao(nome_usuario))
